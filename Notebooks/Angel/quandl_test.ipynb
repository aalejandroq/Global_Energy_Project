# %%
import pandas as pd
import quandl

# %%
# quandl.get("UNAE/GVAKD_URY", authtoken="Pjy4pjUdbZ7yRYkxkzj4")
#quandl.get("UNAE/GVAKD_URY")
# Out:
#             Agriculture; hunting; forestry; fishing (ISIC A-B)  \
# Date
# 1970-12-31                                       1.913328e+09
# 1971-12-31                                       1.793035e+09
# 1972-12-31                                       1.605113e+09
# 1973-12-31                                       1.647007e+09
# 1974-12-31                                       1.700869e+09
# 1975-12-31                                       1.796027e+09
# 1976-12-31                                       1.830140e+09
# 1977-12-31                                       1.888791e+09
# 1978-12-31                                       1.763111e+09
# 1979-12-31                                       1.755331e+09
# 1980-12-31                                       2.039607e+09
# 1981-12-31                                       2.152120e+09
# 1982-12-31                                       1.994123e+09
# 1983-12-31                                       2.036016e+09
# ...

# %%
BRA_df = quandl.get("UNAE/GVACD_BRA")

# %%
BRA_df.head()
# Out:
#             Agriculture; hunting; forestry; fishing (ISIC A-B)  \
# Date
# 1970-12-31                                       3.652180e+09
# 1971-12-31                                       4.370208e+09
# 1972-12-31                                       5.638717e+09
# 1973-12-31                                       7.819866e+09
# 1974-12-31                                       9.797979e+09
#
#             Mining; Manufacturing; Utilities (ISIC C-E)  \
# Date
# 1970-12-31                                 9.623444e+09
# 1971-12-31                                 1.104351e+10
# 1972-12-31                                 1.436938e+10
# 1973-12-31                                 2.213177e+10
# 1974-12-31                                 2.946541e+10
#
#             Manufacturing (ISIC D)  Construction (ISIC F)  \
# Date
# 1970-12-31            8.672670e+09           1.705357e+09
# 1971-12-31            9.937852e+09           1.966593e+09
# ...

# %%
BRA_2_df = quandl.get("UNAE/GVAKD_BRA")

# %%
BRA_2_df.head()
# Out:
#             Agriculture; hunting; forestry; fishing (ISIC A-B)  \
# Date
# 1970-12-31                                       2.157553e+10
# 1971-12-31                                       2.377624e+10
# 1972-12-31                                       2.472729e+10
# 1973-12-31                                       2.475202e+10
# 1974-12-31                                       2.507379e+10
#
#             Mining; Manufacturing; Utilities (ISIC C-E)  \
# Date
# 1970-12-31                                 9.730459e+10
# 1971-12-31                                 1.087866e+11
# 1972-12-31                                 1.242340e+11
# 1973-12-31                                 1.453533e+11
# 1974-12-31                                 1.577085e+11
#
#             Manufacturing (ISIC D)  Construction (ISIC F)  \
# Date
# 1970-12-31            7.275022e+10           2.684677e+10
# 1971-12-31            8.133496e+10           3.001461e+10
# ...

# %%
BRA_2_df.describe()
# Out:
#        Agriculture; hunting; forestry; fishing (ISIC A-B)  \
# count                                       4.800000e+01
# mean                                        5.696842e+10
# std                                         2.608904e+10
# min                                         2.157553e+10
# 25%                                         3.683686e+10
# 50%                                         4.880553e+10
# 75%                                         7.834912e+10
# max                                         1.071098e+11
#
#        Mining; Manufacturing; Utilities (ISIC C-E)  Manufacturing (ISIC D)  \
# count                                 4.800000e+01            4.800000e+01
# mean                                  2.729176e+11            1.986851e+11
# std                                   8.305836e+10            5.632510e+10
# min                                   9.730459e+10            7.275022e+10
# ...

# %%
RUS_df = quandl.get("UNAE/GVAKD_RUS")

# %%
RUS_df.shape
# Out:
# (28, 8)

# %%
RUS_df.head()
# Out:
#             Agriculture; hunting; forestry; fishing (ISIC A-B)  \
# Date
# 1990-12-31                                       6.644247e+10
# 1991-12-31                                       6.398072e+10
# 1992-12-31                                       5.822287e+10
# 1993-12-31                                       5.589396e+10
# 1994-12-31                                       4.929516e+10
#
#             Mining; Manufacturing; Utilities (ISIC C-E)  \
# Date
# 1990-12-31                                 4.726896e+11
# 1991-12-31                                 4.457487e+11
# 1992-12-31                                 3.659156e+11
# 1993-12-31                                 3.131072e+11
# 1994-12-31                                 2.503759e+11
#
#             Manufacturing (ISIC D)  Construction (ISIC F)  \
# Date
# 1990-12-31            2.444101e+11           1.202085e+11
# 1991-12-31            2.304832e+11           1.057874e+11
# ...

# %%
RUS_df.iloc[0]
# Out:
# Agriculture; hunting; forestry; fishing (ISIC A-B)            6.644247e+10
# Mining; Manufacturing; Utilities (ISIC C-E)                   4.726896e+11
# Manufacturing (ISIC D)                                        2.444101e+11
# Construction (ISIC F)                                         1.202085e+11
# Wholesale; retail trade; restaurants and hotels (ISIC G-H)    1.388710e+11
# Transport; storage and communication (ISIC I)                 1.383119e+11
# Other Activities (ISIC J-P)                                   3.020482e+11
# Total Value Added                                             1.226269e+12
# Name: 1990-12-31 00:00:00, dtype: float64

# %%
a=RUS_df.iloc[0]

# %%
b = a/sum(a[:-1])

# %%
b
# Out:
# Agriculture; hunting; forestry; fishing (ISIC A-B)            0.044803
# Mining; Manufacturing; Utilities (ISIC C-E)                   0.318743
# Manufacturing (ISIC D)                                        0.164810
# Construction (ISIC F)                                         0.081059
# Wholesale; retail trade; restaurants and hotels (ISIC G-H)    0.093643
# Transport; storage and communication (ISIC I)                 0.093266
# Other Activities (ISIC J-P)                                   0.203676
# Total Value Added                                             0.826894
# Name: 1990-12-31 00:00:00, dtype: float64

# %%
sum(b[:-1])
# Out:
# 0.9999999999999999

# %%
a_BRA=BRA_2_df.iloc[0]
a_BRA
# Out:
# Agriculture; hunting; forestry; fishing (ISIC A-B)            2.157553e+10
# Mining; Manufacturing; Utilities (ISIC C-E)                   9.730459e+10
# Manufacturing (ISIC D)                                        7.275022e+10
# Construction (ISIC F)                                         2.684677e+10
# Wholesale; retail trade; restaurants and hotels (ISIC G-H)    4.672263e+10
# Transport; storage and communication (ISIC I)                 2.399507e+10
# Other Activities (ISIC J-P)                                   1.512378e+11
# Total Value Added                                             3.639299e+11
# Name: 1970-12-31 00:00:00, dtype: float64

# %%
b_BRA = a_BRA/sum(a_BRA[:-1])
b_BRA
# Out:
# Agriculture; hunting; forestry; fishing (ISIC A-B)            0.048987
# Mining; Manufacturing; Utilities (ISIC C-E)                   0.220930
# Manufacturing (ISIC D)                                        0.165179
# Construction (ISIC F)                                         0.060955
# Wholesale; retail trade; restaurants and hotels (ISIC G-H)    0.106083
# Transport; storage and communication (ISIC I)                 0.054481
# Other Activities (ISIC J-P)                                   0.343385
# Total Value Added                                             0.826301
# Name: 1970-12-31 00:00:00, dtype: float64

# %%
test_df = quandl.get(["UNAE/GVACD_BRA", "UNAE/GVAKD_RUS"],authtoken="Pjy4pjUdbZ7yRYkxkzj4")
# test_df = quandl.get("UNAE/GVACD_BRA")

# %%
test_df.head()
# Out:
#             UNAE/GVACD_BRA - Agriculture; hunting; forestry; fishing (ISIC A-B)  \
# Date
# 1970-12-31                                       3.652180e+09
# 1971-12-31                                       4.370208e+09
# 1972-12-31                                       5.638717e+09
# 1973-12-31                                       7.819866e+09
# 1974-12-31                                       9.797979e+09
#
#             UNAE/GVACD_BRA - Mining; Manufacturing; Utilities (ISIC C-E)  \
# Date
# 1970-12-31                                       9.623444e+09
# 1971-12-31                                       1.104351e+10
# 1972-12-31                                       1.436938e+10
# 1973-12-31                                       2.213177e+10
# 1974-12-31                                       2.946541e+10
#
#             UNAE/GVACD_BRA - Manufacturing (ISIC D)  \
# Date
# 1970-12-31                             8.672670e+09
# 1971-12-31                             9.937852e+09
# ...

# %%
authtoken="Pjy4pjUdbZ7yRYkxkzj4"

# %%
#*******************************************************

# %%
tickers = pd.read_csv('ticker_list.csv')
tickers.head()
# Out:
#       Country  Code         Q_Ticker
# 0       World  5001  UNAE/GVAKD_5001
# 1     Belgium   BEL   UNAE/GVAKD_BEL
# 2  Czech Rep.   CZE   UNAE/GVAKD_CZE
# 3      France   FRA   UNAE/GVAKD_FRA
# 4     Germany   DEU   UNAE/GVAKD_DEU

# %%
tickers.Country[16]
# Out:
# 'Russia'

# %%
RUS_df.head()
# Out:
#             Agriculture; hunting; forestry; fishing (ISIC A-B)  \
# Date
# 1990-12-31                                       6.644247e+10
# 1991-12-31                                       6.398072e+10
# 1992-12-31                                       5.822287e+10
# 1993-12-31                                       5.589396e+10
# 1994-12-31                                       4.929516e+10
#
#             Mining; Manufacturing; Utilities (ISIC C-E)  \
# Date
# 1990-12-31                                 4.726896e+11
# 1991-12-31                                 4.457487e+11
# 1992-12-31                                 3.659156e+11
# 1993-12-31                                 3.131072e+11
# 1994-12-31                                 2.503759e+11
#
#             Manufacturing (ISIC D)  Construction (ISIC F)  \
# Date
# 1990-12-31            2.444101e+11           1.202085e+11
# 1991-12-31            2.304832e+11           1.057874e+11
# ...

# %%
a=RUS_df.reset_index()
a.head()
# Out:
#         Date  Agriculture; hunting; forestry; fishing (ISIC A-B)  \
# 0 1990-12-31                                       6.644247e+10
# 1 1991-12-31                                       6.398072e+10
# 2 1992-12-31                                       5.822287e+10
# 3 1993-12-31                                       5.589396e+10
# 4 1994-12-31                                       4.929516e+10
#
#    Mining; Manufacturing; Utilities (ISIC C-E)  Manufacturing (ISIC D)  \
# 0                                 4.726896e+11            2.444101e+11
# 1                                 4.457487e+11            2.304832e+11
# 2                                 3.659156e+11            1.892012e+11
# 3                                 3.131072e+11            1.618938e+11
# 4                                 2.503759e+11            1.294673e+11
#
#    Construction (ISIC F)  \
# 0           1.202085e+11
# 1           1.057874e+11
# 2           7.087659e+10
# 3           6.520645e+10
# ...

# %%
# a['Date'] = a['Date']
pd.year[a['Date']]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-dbfafdc2c1ec> in <module>
#       1 # a['Date'] = a['Date']
# ----> 2 pd.year[a['Date']]
#
# AttributeError: module 'pandas' has no attribute 'year'

# %%
a.dtypes
# Out:
# Date                                                          datetime64[ns]
# Agriculture; hunting; forestry; fishing (ISIC A-B)                   float64
# Mining; Manufacturing; Utilities (ISIC C-E)                          float64
# Manufacturing (ISIC D)                                               float64
# Construction (ISIC F)                                                float64
# Wholesale; retail trade; restaurants and hotels (ISIC G-H)           float64
# Transport; storage and communication (ISIC I)                        float64
# Other Activities (ISIC J-P)                                          float64
# Total Value Added                                                    float64
# dtype: object

# %%
a['Date'].year()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-a2c1c97e5c33> in <module>
# ----> 1 a['Date'].year()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'year'

# %%
a['Date'] = pd.DatetimeIndex(a['Date']).year

# %%
a.head()
# Out:
#    Date  Agriculture; hunting; forestry; fishing (ISIC A-B)  \
# 0  1990                                       6.644247e+10
# 1  1991                                       6.398072e+10
# 2  1992                                       5.822287e+10
# 3  1993                                       5.589396e+10
# 4  1994                                       4.929516e+10
#
#    Mining; Manufacturing; Utilities (ISIC C-E)  Manufacturing (ISIC D)  \
# 0                                 4.726896e+11            2.444101e+11
# 1                                 4.457487e+11            2.304832e+11
# 2                                 3.659156e+11            1.892012e+11
# 3                                 3.131072e+11            1.618938e+11
# 4                                 2.503759e+11            1.294673e+11
#
#    Construction (ISIC F)  \
# 0           1.202085e+11
# 1           1.057874e+11
# 2           7.087659e+10
# 3           6.520645e+10
# 4           5.281723e+10
#
# ...

# %%
#Reaname columns
a.columns =["Year","Agriculture","Mining","Manufacturing","Construction","Wholesale","Transport","Other","Total"]
a.head()
# Out:
#    Year   Agriculture        Mining  Manufacturing  Construction  \
# 0  1990  6.644247e+10  4.726896e+11   2.444101e+11  1.202085e+11
# 1  1991  6.398072e+10  4.457487e+11   2.304832e+11  1.057874e+11
# 2  1992  5.822287e+10  3.659156e+11   1.892012e+11  7.087659e+10
# 3  1993  5.589396e+10  3.131072e+11   1.618938e+11  6.520645e+10
# 4  1994  4.929516e+10  2.503759e+11   1.294673e+11  5.281723e+10
#
#       Wholesale     Transport         Other         Total
# 0  1.388710e+11  1.383119e+11  3.020482e+11  1.226269e+12
# 1  1.341787e+11  1.303391e+11  3.048563e+11  1.175323e+12
# 2  1.277053e+11  1.093772e+11  2.872629e+11  1.012969e+12
# 3  1.237465e+11  8.734320e+10  2.924582e+11  9.401008e+11
# 4  1.236227e+11  7.327257e+10  2.629838e+11  8.156882e+11

# %%
# tickers.Country[16]
a['Country'] = tickers.Country[16]
a.head()
# Out:
#    Year   Agriculture        Mining  Manufacturing  Construction  \
# 0  1990  6.644247e+10  4.726896e+11   2.444101e+11  1.202085e+11
# 1  1991  6.398072e+10  4.457487e+11   2.304832e+11  1.057874e+11
# 2  1992  5.822287e+10  3.659156e+11   1.892012e+11  7.087659e+10
# 3  1993  5.589396e+10  3.131072e+11   1.618938e+11  6.520645e+10
# 4  1994  4.929516e+10  2.503759e+11   1.294673e+11  5.281723e+10
#
#       Wholesale     Transport         Other         Total Country
# 0  1.388710e+11  1.383119e+11  3.020482e+11  1.226269e+12  Russia
# 1  1.341787e+11  1.303391e+11  3.048563e+11  1.175323e+12  Russia
# 2  1.277053e+11  1.093772e+11  2.872629e+11  1.012969e+12  Russia
# 3  1.237465e+11  8.734320e+10  2.924582e+11  9.401008e+11  Russia
# 4  1.236227e+11  7.327257e+10  2.629838e+11  8.156882e+11  Russia

# %%
# Calculate Total column
a['Total'] = a.loc[:,'Agriculture':'Other'].sum(axis=1)

# %%
a.head()
# Out:
#    Year   Agriculture        Mining  Manufacturing  Construction  \
# 0  1990  6.644247e+10  4.726896e+11   2.444101e+11  1.202085e+11
# 1  1991  6.398072e+10  4.457487e+11   2.304832e+11  1.057874e+11
# 2  1992  5.822287e+10  3.659156e+11   1.892012e+11  7.087659e+10
# 3  1993  5.589396e+10  3.131072e+11   1.618938e+11  6.520645e+10
# 4  1994  4.929516e+10  2.503759e+11   1.294673e+11  5.281723e+10
#
#       Wholesale     Transport         Other         Total Country
# 0  1.388710e+11  1.383119e+11  3.020482e+11  1.482982e+12  Russia
# 1  1.341787e+11  1.303391e+11  3.048563e+11  1.415374e+12  Russia
# 2  1.277053e+11  1.093772e+11  2.872629e+11  1.208562e+12  Russia
# 3  1.237465e+11  8.734320e+10  2.924582e+11  1.099649e+12  Russia
# 4  1.236227e+11  7.327257e+10  2.629838e+11  9.418346e+11  Russia

# %%
#Create new df with desired column order
aa = a[ ['Country'] + [ col for col in a.columns if col != 'Country' ] ]

# %%
aa.head()
# Out:
#   Country  Year   Agriculture        Mining  Manufacturing  Construction  \
# 0  Russia  1990  6.644247e+10  4.726896e+11   2.444101e+11  1.202085e+11
# 1  Russia  1991  6.398072e+10  4.457487e+11   2.304832e+11  1.057874e+11
# 2  Russia  1992  5.822287e+10  3.659156e+11   1.892012e+11  7.087659e+10
# 3  Russia  1993  5.589396e+10  3.131072e+11   1.618938e+11  6.520645e+10
# 4  Russia  1994  4.929516e+10  2.503759e+11   1.294673e+11  5.281723e+10
#
#       Wholesale     Transport         Other         Total
# 0  1.388710e+11  1.383119e+11  3.020482e+11  1.482982e+12
# 1  1.341787e+11  1.303391e+11  3.048563e+11  1.415374e+12
# 2  1.277053e+11  1.093772e+11  2.872629e+11  1.208562e+12
# 3  1.237465e+11  8.734320e+10  2.924582e+11  1.099649e+12
# 4  1.236227e+11  7.327257e+10  2.629838e+11  9.418346e+11

# %%
df_new = df.loc[:,"value1":"value3"].div(df["sum"], axis=0)

# %%
aaa = aa[['Country']+aa['Year']+aa.loc[:,'Agriculture':'Total'].div(aa['Total'],axis=0)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1504         try:
# -> 1505             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1506         except TypeError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     209     return _evaluate_standard(op, op_str, a, b)
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     122     if result is None:
# --> 123         result = _evaluate_standard(op, op_str, a, b)
#     124
#
# ...

# %%
aa.head()
# Out:
#   Country  Year   Agriculture        Mining  Manufacturing  Construction  \
# 0  Russia  1990  6.644247e+10  4.726896e+11   2.444101e+11  1.202085e+11
# 1  Russia  1991  6.398072e+10  4.457487e+11   2.304832e+11  1.057874e+11
# 2  Russia  1992  5.822287e+10  3.659156e+11   1.892012e+11  7.087659e+10
# 3  Russia  1993  5.589396e+10  3.131072e+11   1.618938e+11  6.520645e+10
# 4  Russia  1994  4.929516e+10  2.503759e+11   1.294673e+11  5.281723e+10
#
#       Wholesale     Transport         Other         Total
# 0  1.388710e+11  1.383119e+11  3.020482e+11  1.482982e+12
# 1  1.341787e+11  1.303391e+11  3.048563e+11  1.415374e+12
# 2  1.277053e+11  1.093772e+11  2.872629e+11  1.208562e+12
# 3  1.237465e+11  8.734320e+10  2.924582e+11  1.099649e+12
# 4  1.236227e+11  7.327257e+10  2.629838e+11  9.418346e+11
